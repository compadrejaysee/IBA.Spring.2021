# %%
import Excalibur as tmp

# %%
file_path = 'telecom_users.csv'
label = 'Churn'
teldf =tmp.load_file(file_path)

# %%
teldf[label]
# Out:
# 0        No
# 1        No
# 2       Yes
# 3        No
# 4        No
#        ...
# 5981    Yes
# 5982     No
# 5983     No
# 5984    Yes
# 5985     No
# Name: Churn, Length: 5986, dtype: object

# %%
teldf = tmp.remove_col(teldf, 'Unnamed: 0')
teldf = tmp.remove_col(teldf, 'customerID')

# %%
# visualize the target variable
import matplotlib.pyplot as plt  
import seaborn as sns
g = sns.countplot(teldf[label])
g.set_xticklabels(['Yes','No'])
plt.show()

# %%
tmp.check_dataset(teldf,5)
# Out:
# (   gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
#  0    Male              0     Yes        Yes      72          Yes
#  1  Female              0      No         No      44          Yes
#  2  Female              1     Yes         No      38          Yes
#  3    Male              0      No         No       4          Yes
#  4    Male              0      No         No       2          Yes
#
#    MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
#  0           Yes              No  No internet service  No internet service
#  1            No     Fiber optic                   No                  Yes
#  2           Yes     Fiber optic                   No                   No
#  3            No             DSL                   No                   No
#  4            No             DSL                  Yes                   No
#
#        DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
 teldf.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
teldf.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
teldf.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
tmp.num_data_analysis(teldf)
# Out:
# ['SeniorCitizen']
# 1790.0671859795984 0.0
# The null hypothesis can be rejected
# ['tenure']
# 65890.02098907482 0.0
# The null hypothesis can be rejected
# ['MonthlyCharges']
# 9937.571430101696 0.0
# The null hypothesis can be rejected
# <bound method NDFrame.describe of       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0       Male              0     Yes        Yes      72          Yes
# 1     Female              0      No         No      44          Yes
# 2     Female              1     Yes         No      38          Yes
# 3       Male              0      No         No       4          Yes
# 4       Male              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 5981    Male              0     Yes         No       1          Yes
# 5982  Female              0     Yes        Yes      23          Yes
# 5983    Male              0     Yes        Yes      12          Yes
# ...

# %%
#Convertin the predictor variable in a binary numeric variable
teldf[label].replace(to_replace='Yes', value=1, inplace=True)
teldf[label].replace(to_replace='No',  value=0, inplace=True)

# %%
teldf = tmp.onehotencoding(teldf)

# %%
#all algorithm without cross validation, Feature selection and regularization
alg_without_cv_fs_reg = tmp.run_algorithms(teldf, label)
# Out:
# ============ LogReg ===========
# Prediction Vector:
#  [1 0 1 ... 0 1 0]
#
#  Accuracy:
#  80.55091819699499
#
#  Precision of event Happening:
#  69.17562724014337
#
#  Recall of event Happening:
#  56.76470588235294
#
#  AUC:
#  0.7337069792952146
#
#  F-Score:
#  0.6235864297253635
#
#  Confusion Matrix:
#  [[772  86]
#  [147 193]]
# AUC Plot
# ...
#
# ============ KNN ===========
# Prediction Vector:
#  [1 0 1 ... 0 1 1]
#
#  Accuracy:
#  77.12854757929884
#
#  Precision of event Happening:
#  61.458333333333336
#
#  Recall of event Happening:
#  52.05882352941177
#
#  AUC:
#  0.6956088029617441
#
#  F-Score:
#  0.5636942675159237
#
#  Confusion Matrix:
#  [[747 111]
#  [163 177]]
# AUC Plot
# ...
#
# ============ GadientBoosting ===========
# Prediction Vector:
#  [1 0 1 ... 0 1 0]
#
#  Accuracy:
#  80.46744574290484
#
#  Precision of event Happening:
#  71.2
#
#  Recall of event Happening:
#  52.352941176470594
#
#  AUC:
#  0.7198066639243109
#
#  F-Score:
#  0.6033898305084745
#
# ...

# %%
#all algorithm with Feature selection only
with_RFF = tmp.MachineLearningwithRFFS(teldf, label)
# Out:
# tenure                            10.135264
# MonthlyCharges                     8.800617
# Contract_Month-to-month            3.305955
# OnlineSecurity_No                  3.220886
# PaymentMethod_Electronic check     2.138924
#                                     ...
# TotalCharges_450.65                0.000000
# TotalCharges_2209.15               0.000000
# TotalCharges_78.05                 0.000000
# TotalCharges_2208.05               0.000000
# TotalCharges_7657.4                0.000000
# Length: 5655, dtype: float64
# Selected Features =['tenure', 'MonthlyCharges']
# (5986, 5656)
# ============ LogReg ===========
# Prediction Vector:
#  [0 0 1 ... 0 1 0]
#
#  Accuracy:
#  78.21368948247078
#
#  Precision of event Happening:
#  67.24890829694323
#
#  Recall of event Happening:
#  45.294117647058826
#
#  AUC:
#  0.6827642945290004
#
#  F-Score:
#  0.5413005272407733
#
#  Confusion Matrix:
#  [[783  75]
#  [186 154]]
# AUC Plot
# ...
#
# ============ KNN ===========
# ...

# %%
#all algo with Lasso (Lasso as Feature selection)
reg_with_lasso = tmp.MachineLearningwithLassoFS(teldf, label)
# Out:
# tenure                 0.727911
# MonthlyCharges         0.421511
# TotalCharges_999.9     0.000000
# TotalCharges_25.15     0.000000
# TotalCharges_2495.2    0.000000
#                          ...
# TotalCharges_5163      0.000000
# TotalCharges_5163.3    0.000000
# TotalCharges_5165.7    0.000000
# TotalCharges_5166.2    0.000000
# SeniorCitizen          0.000000
# Length: 5655, dtype: float64
# Selected Features =['tenure', 'MonthlyCharges']
# (5986, 5656)
# ============ LogReg ===========
# Prediction Vector:
#  [0 0 1 ... 0 1 0]
#
#  Accuracy:
#  78.21368948247078
#
#  Precision of event Happening:
#  67.24890829694323
#
#  Recall of event Happening:
#  45.294117647058826
#
#  AUC:
#  0.6827642945290004
#
#  F-Score:
#  0.5413005272407733
#
#  Confusion Matrix:
#  [[783  75]
#  [186 154]]
# AUC Plot
# ...
#
# ============ KNN ===========
# Prediction Vector:
#  [1 0 1 ... 0 1 1]
#
#  Accuracy:
#  76.37729549248748
#
#  Precision of event Happening:
#  60.91954022988506
#
# ...

# %%
#all algorithm with CV only
with_CV = tmp.MachineLearningwith_CV(teldf, label)
# Out:
# [09:31:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:31:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:32:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
#all algo with RF and CV
tmp.MachineLearningwith_cls_imb_RFFS_CV(teldf, label)
# Out:
# tenure                         10.370786
# MonthlyCharges                  7.962057
# Contract_Month-to-month         3.629147
# InternetService_Fiber optic     2.388508
# OnlineSecurity_No               2.285086
#                                  ...
# TotalCharges_450.9              0.000000
# TotalCharges_4509.5             0.000000
# TotalCharges_451.1              0.000000
# TotalCharges_7349.35            0.000000
# TotalCharges_215.8              0.000000
# Length: 5655, dtype: float64
# Selected Features =['tenure', 'MonthlyCharges']
# (5986, 5656)
# [12:28:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...
