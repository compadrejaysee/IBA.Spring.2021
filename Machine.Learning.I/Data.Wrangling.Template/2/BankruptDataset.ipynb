# %%
import Excalibur as tmp

# %%
file_path = 'data.csv'
label = 'Bankrupt?'
bndf =tmp.load_file(file_path)

# %%
bndf[label]
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 6814    0
# 6815    0
# 6816    0
# 6817    0
# 6818    0
# Name: Bankrupt?, Length: 6819, dtype: int64

# %%
tmp.check_dataset(bndf,5)
# Out:
# (   Bankrupt?   ROA(C) before interest and depreciation before interest  \
#  0          1                                           0.370594
#  1          1                                           0.464291
#  2          1                                           0.426071
#  3          1                                           0.399844
#  4          1                                           0.465022
#
#      ROA(A) before interest and % after tax  \
#  0                                 0.424389
#  1                                 0.538214
#  2                                 0.499019
#  3                                 0.451265
#  4                                 0.538432
#
#      ROA(B) before interest and depreciation after tax  \
#  0                                           0.405750
#  1                                           0.516730
#  2                                           0.472295
#  3                                           0.457733
# ...

# %%
 bndf.dtypes
# Out:
# Bankrupt?                                                     int64
#  ROA(C) before interest and depreciation before interest    float64
#  ROA(A) before interest and % after tax                     float64
#  ROA(B) before interest and depreciation after tax          float64
#  Operating Gross Margin                                     float64
#                                                              ...
#  Liability to Equity                                        float64
#  Degree of Financial Leverage (DFL)                         float64
#  Interest Coverage Ratio (Interest expense to EBIT)         float64
#  Net Income Flag                                              int64
#  Equity to Liability                                        float64
# Length: 96, dtype: object

# %%
bndf.isnull().sum()
# Out:
# Bankrupt?                                                   0
#  ROA(C) before interest and depreciation before interest    0
#  ROA(A) before interest and % after tax                     0
#  ROA(B) before interest and depreciation after tax          0
#  Operating Gross Margin                                     0
#                                                            ..
#  Liability to Equity                                        0
#  Degree of Financial Leverage (DFL)                         0
#  Interest Coverage Ratio (Interest expense to EBIT)         0
#  Net Income Flag                                            0
#  Equity to Liability                                        0
# Length: 96, dtype: int64

# %%
bndf.columns
# Out:
# Index(['Bankrupt?', ' ROA(C) before interest and depreciation before interest',
#        ' ROA(A) before interest and % after tax',
#        ' ROA(B) before interest and depreciation after tax',
#        ' Operating Gross Margin', ' Realized Sales Gross Margin',
#        ' Operating Profit Rate', ' Pre-tax net Interest Rate',
#        ' After-tax net Interest Rate',
#        ' Non-industry income and expenditure/revenue',
#        ' Continuous interest rate (after tax)', ' Operating Expense Rate',
#        ' Research and development expense rate', ' Cash flow rate',
#        ' Interest-bearing debt interest rate', ' Tax rate (A)',
#        ' Net Value Per Share (B)', ' Net Value Per Share (A)',
#        ' Net Value Per Share (C)', ' Persistent EPS in the Last Four Seasons',
#        ' Cash Flow Per Share', ' Revenue Per Share (Yuan ¥)',
#        ' Operating Profit Per Share (Yuan ¥)',
#        ' Per Share Net profit before tax (Yuan ¥)',
# ...

# %%
tmp.num_data_analysis(bndf)
# Out:
# ['Bankrupt?']
# 6871.189783660709 0.0
# The null hypothesis can be rejected
# [' ROA(C) before interest and depreciation before interest']
# 1015.8027068766094 2.637818140133172e-221
# The null hypothesis can be rejected
# [' ROA(A) before interest and % after tax']
# 1976.6237094705657 0.0
# The null hypothesis can be rejected
# [' ROA(B) before interest and depreciation after tax']
# 1569.5464117030408 0.0
# The null hypothesis can be rejected
# [' Operating Gross Margin']
# 10064.766875309753 0.0
# The null hypothesis can be rejected
# [' Realized Sales Gross Margin']
# 10079.42174715768 0.0
# The null hypothesis can be rejected
# [' Operating Profit Rate']
# 24207.308971627674 0.0
# The null hypothesis can be rejected
# [' Pre-tax net Interest Rate']
# 21881.500517181288 0.0
# The null hypothesis can be rejected
# [' After-tax net Interest Rate']
# 21951.803074418425 0.0
# The null hypothesis can be rejected
# [' Non-industry income and expenditure/revenue']
# ...

# %%
#all algorithm without cross validation, Feature selection and regularization
alg_without_cv_fs_reg = tmp.run_algorithms(bndf, label)
# Out:
# ============ LogReg ===========
# No handles with labels found to put in legend.
# Prediction Vector:
#  [0 0 0 ... 0 0 0]
#
#  Accuracy:
#  96.04105571847508
#
#  Precision of event Happening:
#  0.0
#
#  Recall of event Happening:
#  0.0
#
#  AUC:
#  0.4962121212121212
#
#  F-Score:
#  0.0
#
#  Confusion Matrix:
#  [[1310   10]
#  [  44    0]]
# AUC Plot
# ...
#
# ============ KNN ===========
# No handles with labels found to put in legend.
# Prediction Vector:
#  [0 0 0 ... 0 0 0]
#
#  Accuracy:
#  96.7008797653959
#
#  Precision of event Happening:
#  0.0
#
#  Recall of event Happening:
#  0.0
#
#  AUC:
#  0.49962121212121213
#
#  F-Score:
#  0.0
#
#  Confusion Matrix:
#  [[1319    1]
#  [  44    0]]
# AUC Plot
# ...
#
# ============ GadientBoosting ===========
# No handles with labels found to put in legend.
# Prediction Vector:
#  [0 0 0 ... 0 0 0]
#
#  Accuracy:
#  96.7008797653959
#
#  Precision of event Happening:
#  48.275862068965516
#
#  Recall of event Happening:
# ...

# %%
#all algorithm with Feature selection only
with_RFFS = tmp.MachineLearningwithRFFS(bndf, label)
# Out:
#  Net Value Growth Rate                    3.544598
#  Net Value Per Share (C)                  2.779809
#  Net profit before tax/Paid-in capital    2.704558
#  Net Income to Stockholder's Equity       2.377980
#  Net Value Per Share (B)                  2.323294
#                                             ...
#  Cash Flow to Equity                      0.465658
#  Contingent liabilities/Net worth         0.431996
#  Tax rate (A)                             0.141328
#  Net Income Flag                          0.000000
#  Liability-Assets Flag                    0.000000
# Length: 95, dtype: float64
# Selected Features =[]
# (6819, 96)
# ============ LogReg ===========
# Prediction Vector:
#  [0 0 0 ... 0 0 0]
#
#  Accuracy:
#  96.04105571847508
#
#  Precision of event Happening:
#  0.0
#
#  Recall of event Happening:
#  0.0
#
#  AUC:
#  0.4962121212121212
#
#  F-Score:
#  0.0
#
#  Confusion Matrix:
#  [[1310   10]
#  [  44    0]]
# AUC Plot
# ...
#
# ============ KNN ===========
# ...

# %%
#all algo with Lasso (AS FS)
reg_with_lasso = tmp.MachineLearningwithLassoFS(bndf, label)
# Out:
#  Fixed Assets to Assets                                     1.124008e-08
#  Net Value Growth Rate                                      9.859405e-09
#  Revenue per person                                         5.637804e-09
#  Revenue Per Share (Yuan ¥)                                 5.152362e-09
#  Total debt/Total net worth                                 4.996239e-09
#                                                                 ...
#  Inventory/Working Capital                                  0.000000e+00
#  Current Liabilities/Liability                              0.000000e+00
#  Working Capital/Equity                                     0.000000e+00
#  Current Liabilities/Equity                                 0.000000e+00
#  ROA(C) before interest and depreciation before interest    0.000000e+00
# Length: 95, dtype: float64
# ...

# %%
#all algorithm with CV only
with_CV = tmp.MachineLearningwith_CV(bndf, label)
# Out:
# [06:06:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [06:06:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [06:06:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
#all algo with RF and CV
tmp.MachineLearningwith_cls_imb_RFFS_CV(bndf, label)
# Out:
#  Net Value Growth Rate                                 7.513911
#  Persistent EPS in the Last Four Seasons               3.721732
#  Net Income to Stockholder's Equity                    3.169628
#  Non-industry income and expenditure/revenue           2.169376
#  Interest Coverage Ratio (Interest expense to EBIT)    2.120846
#                                                          ...
#  Current Assets/Total Assets                           0.189987
#  Liability-Assets Flag                                 0.173531
#  CFO to Assets                                         0.147737
#  Current Liability to Liability                        0.000000
#  Net Income Flag                                       0.000000
# Length: 95, dtype: float64
# Selected Features =[' Net Value Growth Rate']
# (6819, 96)
# ...
